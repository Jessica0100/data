# %% [markdown]
# <a href="https://colab.research.google.com/github/Jessica0100/data/blob/main/21_209_UTSdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DATA UNDERSTANDING**

# %%
# Import library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("/content/drive/MyDrive/dataUTS/cirrhosis.csv")

# 1. Informasi umum
print("🔹 Informasi Dataset:")
print(df.info())

# 2. Beberapa baris awal
print("\n🔹 Contoh Data:")
display(df.head())

# 3. Statistik deskriptif
print("\n🔹 Statistik Deskriptif:")
display(df.describe(include='all'))

# 4. Jumlah missing values
print("\n🔹 Missing Values Tiap Kolom:")
print(df.isnull().sum())

# 5. Distribusi target (Status)
print("\n🔹 Distribusi Kelas Target (Status):")
print(df['Status'].value_counts())

sns.countplot(data=df, x='Status')
plt.title("Distribusi Kelas Status")
plt.show()

# 6. Visualisasi distribusi fitur numerik
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()

num_cols = 4
num_rows = int(len(numerical_cols) / num_cols) + (len(numerical_cols) % num_cols > 0)

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(num_rows, num_cols, i)
    sns.histplot(df[col], kde=True, bins=30, color='teal')
    plt.title(f'Distribusi {col}')
    plt.tight_layout()

plt.suptitle("Distribusi Fitur Numerik", y=1.02, fontsize=16)
plt.show()
# Out:
# 🔹 Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             418 non-null    int64
#  1   N_Days         418 non-null    int64
#  2   Status         418 non-null    object
#  3   Drug           312 non-null    object
#  4   Age            418 non-null    int64
#  5   Sex            418 non-null    object
#  6   Ascites        312 non-null    object
#  7   Hepatomegaly   312 non-null    object
#  8   Spiders        312 non-null    object
#  9   Edema          418 non-null    object
#  10  Bilirubin      418 non-null    float64
#  11  Cholesterol    284 non-null    float64
#  12  Albumin        418 non-null    float64
#  13  Copper         310 non-null    float64
#  14  Alk_Phos       312 non-null    float64
#  15  SGOT           312 non-null    float64
#  16  Tryglicerides  282 non-null    float64
# ...

# %% [markdown]
# PREPOCESSING

# %%
# Import library yang dibutuhkan
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# Load dataset
df = pd.read_csv("/content/drive/MyDrive/dataUTS/cirrhosis.csv")

# 1. Hapus kolom ID (bukan fitur yang berguna)
df.drop(columns=["ID"], inplace=True)

# 2. Imputasi nilai kosong
# Imputasi fitur numerik dengan median
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
imputer_num = SimpleImputer(strategy='median')
df[num_cols] = imputer_num.fit_transform(df[num_cols])

# Imputasi fitur kategorikal dengan modus (frekuensi terbanyak)
cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode().iloc[0])

# 3. Label encoding untuk fitur kategorikal
label_encoders = {}
for col in cat_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# 4. Pisahkan fitur dan label
X = df.drop(columns=["Status"])  # fitur
y = df["Status"]                # label

# 5. Normalisasi/Standardisasi fitur
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 6. Bagi data menjadi train dan test set
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

print("Preprocessing selesai. Data siap untuk modeling.")
# Out:
# Preprocessing selesai. Data siap untuk modeling.

# %% [markdown]
# **MODELING**

# %%
# Import library untuk modeling
from sklearn.ensemble import RandomForestClassifier

# Inisialisasi dan training model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Prediksi pada data uji
y_pred = model.predict(X_test)

print("Model Random Forest telah dilatih dan prediksi selesai.")
# Out:
# Model Random Forest telah dilatih dan prediksi selesai.

# %% [markdown]
# **EVALUASI**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Classification Report
report = classification_report(y_test, y_pred)
print("📄 Classification Report:\n")
print(report)

# Accuracy
acc = accuracy_score(y_test, y_pred)
print(f"🎯 Accuracy: {acc:.2f}")
# Out:
# 📄 Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79        47
#            1       0.00      0.00      0.00         5
#            2       0.73      0.69      0.71        32
#
#     accuracy                           0.74        84
#    macro avg       0.49      0.51      0.50        84
# weighted avg       0.69      0.74      0.71        84
#
# 🎯 Accuracy: 0.74
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# **WEB STATIS**

# %%
# Pertama, pastikan direktori sudah benar
import os
import shutil

# Buat direktori untuk web statis
web_dir = "/content/cirrhosis_web"
os.makedirs(web_dir, exist_ok=True)

# Salin semua file yang dibutuhkan ke dalam direktori
#shutil.copy("cirrhosis_web/index.html", web_dir)
#shutil.copy("cirrhosis_web/confusion_matrix.png", web_dir)
#shutil.copy("cirrhosis_web/classification_report.html", web_dir)

# Jika ada profil_data.html, salin juga
if os.path.exists("profil_data.html"):
    shutil.copy("profil_data.html", web_dir)

# Kompres direktori web ke dalam file ZIP
shutil.make_archive("/content/cirrhosis_web", 'zip', web_dir)

print("File ZIP telah selesaiii.")
# Out:
# File ZIP telah selesaiii.
